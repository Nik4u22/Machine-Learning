# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Libraries Automate Exploratory Data Analysis
# We are discussing four important python libraries. These are listed below:
#
# 1. dtale
# 2. pandas profiling
# 3. sweetviz
# 4. autoviz

# %%
# 1. dtale
# !pip install dtale
# Out:
# ...
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62589 sha256=b3dffb7953ff25b5abe313054a098f29146f165199f67b33f50681279062d569
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\ec\32\ec\dc8a1aa820182edf280a5e26c76fc9493ae29e196735708de2
# ...
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669716 sha256=3f41f67588535eec423b9b59e2df662e991371c4e6e7e1828673f2c88779a1d2
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\53\73\ea\8a422aab5cab848d88653ed3087c1fa05553c3fbd67fb6ab75
# Successfully built dash-colorscales dash-daq
# ...
#   Using cached dtale-2.5.1-py2.py3-none-any.whl (12.9 MB)
# ...
#   Using cached dash_daq-0.5.0.tar.gz (642 kB)
# ...
#   Using cached squarify-0.4.3-py3-none-any.whl (4.3 kB)
# ...
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# ...
#   Using cached dash_colorscales-0.0.4.tar.gz (62 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import dtale
import pandas as pd
df = pd.read_csv("E:/Business Analytics/EDA with Data/ProKabaddi_data.csv")
d = dtale.show(df)
d.open_browser()

# %%
# 2. Pandas Profiling
# !pip install pandas-profiling
# Out:
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# ...
#   Using cached phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# ...
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# ...
#   Using cached pydantic-1.9.1-cp39-cp39-win_amd64.whl (2.0 MB)
# ...
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# ...

# %%
#importing required packages
import pandas as pd
import pandas_profiling
import numpy as np

#importing the data
df = pd.read_csv("E:/Business Analytics/EDA with Data/ProKabaddi_data.csv")

#descriptive statistics
pandas_profiling.ProfileReport(df)
# Out:
# 2022-05-31 20:24:22,159 - INFO     - Pandas backend loaded 1.3.4
# 2022-05-31 20:24:22,180 - INFO     - Numpy backend loaded 1.20.3
# 2022-05-31 20:24:22,188 - INFO     - Pyspark backend NOT loaded
# 2022-05-31 20:24:22,188 - INFO     - Python backend loaded
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
# 3. sweetViz
# !pip install sweetviz

# %%
import sweetviz
import pandas as pd
df = pd.read_csv("E:/Business Analytics/EDA with Data/ProKabaddi_data.csv")
my_report  = sweetviz.analyze([df,'Train'], target_feat='')
my_report.show_html('FinalReport.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report FinalReport.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# 4. autoviz
# !pip install autoviz
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\dell\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\dell\\AppData\\Local\\Temp\\pip-install-v734xtyr\\wordcloud_c90f63169436445f80fc9668ce029d83\\setup.py'"'"'; __file__='"'"'C:\\Users\\dell\\AppData\\Local\\Temp\\pip-install-v734xtyr\\wordcloud_c90f63169436445f80fc9668ce029d83\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\dell\AppData\Local\Temp\pip-wheel-mcq4y40g'
#        cwd: C:\Users\dell\AppData\Local\Temp\pip-install-v734xtyr\wordcloud_c90f63169436445f80fc9668ce029d83\
#   Complete output (20 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
df = AV.AutoViz("E:/Business Analytics/EDA with Data/ProKabaddi_data.csv")
